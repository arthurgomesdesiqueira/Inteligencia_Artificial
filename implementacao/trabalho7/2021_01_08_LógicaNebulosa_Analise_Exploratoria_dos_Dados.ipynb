# %% [markdown]
# **Instituto de Informática - UFG**
#
# Disciplina: Inteligência Artificial
#
# Prof. Cedric Luiz de Carvalho
#
#
# Grupo ( D )
#
# ---
#
#
# Aluna(o): Arthur Gomes de Siqueira
#
# ---
#
# Aluna(o): Ricardo Ataide de Oliveira Junior
#
# ---

# %% [markdown]
# #Especificação do problema : Lógica nebulosa

# %% [markdown]
# O setor de aluguéis de imóveis movimenta milhões por ano. Com a pandemia do coronavírus, esse setor tem sido forçado a se reinventar, uma vez que o contato direto (presencial) entre os interessados em alugar um imóvel e os corretores tem sido prejudicado. Você foi contratado por uma empresa do setor para projetar e implementar um sistema que faça sugestões para os clientes de imóveis que possam ser do seu interesse.
#
# Utilizando a base de dados [brazilian_houses_to_rent](https://www.kaggle.com/rubenssjr/brasilian-houses-to-rent), projete e implemente um sistema de recomendação, baseado em lógica nebulosa, que identifique os imóveis mais adequados às necessidades de um determinado cliente.
#
# Nesse projeto, devem ser identificadas as variáveis de entrada nebulosas, as quais devem ter, no mínimo, três faixas valores. Também deve ser definida uma variável de saída que indique a probabilidade do cliente se interessar por um dado imóvel.

# %% [markdown]
# ## O trabalho

# %% [markdown]
# O trabalho deve ser feito em grupos, conforme definido. Cada grupo deverá entregar apenas um produto final para ser avaliado pelo professor. Apesar do trabalho ser feito em grupos, a avaliação de cada aluno será feita individualmente.

# %% [markdown]
# **Recomendações:**
#
#    O primeiro passo para resolver um problema é entendê-lo muito bem, considerar o contexto e fazer as abstrações necessárias. A seguir, para não "reinventar a roda" é preciso identificar como a comunidade resolveu o problema em questão, ou problemas parecidos, cuja solução possa ser mapeada para situação em análise. Desta forma, deve ser feito um estudo, o mais amplo possível sobre esse assunto. O próximo passo é o grupo se reunir e instanciar o modelo em estudo para o caso específico do problema a ser resolvido. Em paralelo, uma análise rigorosa deve ser feita na base de dados a fim de prepará-la para seu uso no modelo. Finalmente, com o modelo bem compreendido e instanciado e os dados devidamente preparados, a implementação do modelo pode ser feita.

# %% [markdown]
# ## Divisão de papéis:

# %% [markdown]
# * **Analista de dados:** deverá ficar responsável por fazer uma "Análise Exploratória de Dados" (AED), analisando a base de dados fornecida e preparando-a para ser usada na solução do problema. Esta análise deve produzir diversos gráficos que pemitam uma visão geral do comportamento dos dados.
#
# * **Engenheiro de conhecimento:** deverá produzir a solução para o problema, utilizando a técnica estudada, o modelo proposto pelo grupo e a base de dados preparada pelo analista de dados.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np 
import plotly.express as px

# %%
#Iniciando a carga dos dados
df1 = pd.read_csv('/content/drive/MyDrive/Raiz/Faculdade/2021.1/IC/Trabalhos/Atividade 8 - Fuzzy/houses_to_rent.csv')
df2 = pd.read_csv('/content/drive/MyDrive/Raiz/Faculdade/2021.1/IC/Trabalhos/Atividade 8 - Fuzzy/houses_to_rent_v2.csv')

# %%
print('=============================================================================')
print('Colunas: ',df1.columns)
print('=============================================================================')
print('Registros: ', len(df1))
# Out:
# =============================================================================
# Colunas:  Index(['Unnamed: 0', 'city', 'area', 'rooms', 'bathroom', 'parking spaces',
#        'floor', 'animal', 'furniture', 'hoa', 'rent amount', 'property tax',
#        'fire insurance', 'total'],
#       dtype='object')
# =============================================================================
# Registros:  6080

# %%
print('=============================================================================')
print('Colunas: ',df2.columns)
print('=============================================================================')
print('Registros: ', len(df2))
# Out:
# =============================================================================
# Colunas:  Index(['city', 'area', 'rooms', 'bathroom', 'parking spaces', 'floor',
#        'animal', 'furniture', 'hoa (R$)', 'rent amount (R$)',
#        'property tax (R$)', 'fire insurance (R$)', 'total (R$)'],
#       dtype='object')
# =============================================================================
# Registros:  10692

# %%
df2.head(5)
# Out:
#            city  area  ...  fire insurance (R$)  total (R$)
# 0     São Paulo    70  ...                   42        5618
# 1     São Paulo   320  ...                   63        7973
# 2  Porto Alegre    80  ...                   41        3841
# 3  Porto Alegre    51  ...                   17        1421
# 4     São Paulo    25  ...                   11         836
#
# [5 rows x 13 columns]

# %%
fig = px.scatter(df2,x='total (R$)',y='area', title='Distribuição dos Dados - V1')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a3f0eae2-a094-4ca8-9e6b-9b342b8f1866" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a3f0eae2-a094-4ca8-9e6b-9b342b8f1866")) {
#                     Plotly.newPlot(
#                         'a3f0eae2-a094-4ca8-9e6b-9b342b8f1866',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "total (R$)=%{x}<br>area=%{y}", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [5618, 7973, 3841, 1421, 836, 8955, 2750, 7253, 16440, 2955, 2747, 1181, 2556, 5268, 5343, 9129, 3861, 5351, 2036, 21680, 3976, 3368, 3622, 1117, 2742, 4067, 3639, 1952, 3328, 2555, 2004, 2266, 4007, 5576, 6651, 2226, 2081, 11610, 1227, 3424, 17440, 3845, 3443, 2335, 12490, 3840, 1947, 2003, 4178, 2185, 5246, 4956, 6452, 1664, 2806, 11540, 6204, 6366, 2276, 4131, 4705, 7416, 3006, 14430, 1868, 8794, 2333, 3857, 1502, 7609, 3030, 1112, 7396, 2728, 2322, 12970, 2633, 3776, 1556, 4354, 8467, 1933, 2992, 6298, 1563, 3418, 19380, 2312, 8027, 4628, 14280, 9520, 4137, 14150, 3316, 3846, 919, 3296, 3035, 2423, 1364, 2883, 2760, 4554, 6149, 2615, 15380, 8900, 2826, 9927, 2266, 13010, 2406, 3231, 9394, 4735, 4745, 3676, 3648, 1418, 3871, 5360, 2145, 5093, 6689, 3999, 10630, 9467, 2063, 3823, 2446, 19640, 1608, 10100, 2252, 3940, 1290, 2089, 2388, 5054, 1775, 2355, 1459, 14880, 10790, 1163, 3078, 2475, 13450, 1191, 2501, 3620, 9094, 4270, 7106, 5333, 4295, 26800, 4972, 2978, 4342, 9566, 1434, 991, 2710, 1789, 2538, 4155, 6666, 11460, 2385, 5506, 9793, 5895, 3282, 3145, 17080, 4262, 4923, 2311, 19040, 2157, 3589, 1615, 2463, 791, 1774, 3543, 13360, 4485, 5064, 11390, 3493, 2176, 1945, 1653, 4042, 2052, 1012, 3672, 7349, 1240, 17310, 1385, 2026, 1546, 7572, 9503, 4860, 5453, 2470, 2040, 3328, 2404, 3889, 3094, 760, 9031, 2589, 7315, 1104, 7212, 1364, 9916, 8115, 1529, 8966, 4412, 1780, 
#Dados duplicados e outliers
df2[df2['total (R$)']== max(df2['total (R$)'])]
df2 = df2.drop(255)
df2 = df2.drop(6979)

# %%
#Valor do seguro muito maior do valor do aluguel 
df2[df2['total (R$)']== max(df2['total (R$)'])]
df2 = df2.drop(6645)

# %%
df2[df2['total (R$)']== max(df2['total (R$)'])]
# Out:
#            city  area  ...  fire insurance (R$)  total (R$)
# 6230  São Paulo   340  ...                  153      233200
#
# [1 rows x 13 columns]

# %%
fig = px.scatter(df2,x='total (R$)',y='area', title = 'Distribuição dos dados após limpeza inicial')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1247bad1-0cda-4d08-8e93-206b86630104" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1247bad1-0cda-4d08-8e93-206b86630104")) {
#                     Plotly.newPlot(
#                         '1247bad1-0cda-4d08-8e93-206b86630104',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "total (R$)=%{x}<br>area=%{y}", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [5618, 7973, 3841, 1421, 836, 8955, 2750, 7253, 16440, 2955, 2747, 1181, 2556, 5268, 5343, 9129, 3861, 5351, 2036, 21680, 3976, 3368, 3622, 1117, 2742, 4067, 3639, 1952, 3328, 2555, 2004, 2266, 4007, 5576, 6651, 2226, 2081, 11610, 1227, 3424, 17440, 3845, 3443, 2335, 12490, 3840, 1947, 2003, 4178, 2185, 5246, 4956, 6452, 1664, 2806, 11540, 6204, 6366, 2276, 4131, 4705, 7416, 3006, 14430, 1868, 8794, 2333, 3857, 1502, 7609, 3030, 1112, 7396, 2728, 2322, 12970, 2633, 3776, 1556, 4354, 8467, 1933, 2992, 6298, 1563, 3418, 19380, 2312, 8027, 4628, 14280, 9520, 4137, 14150, 3316, 3846, 919, 3296, 3035, 2423, 1364, 2883, 2760, 4554, 6149, 2615, 15380, 8900, 2826, 9927, 2266, 13010, 2406, 3231, 9394, 4735, 4745, 3676, 3648, 1418, 3871, 5360, 2145, 5093, 6689, 3999, 10630, 9467, 2063, 3823, 2446, 19640, 1608, 10100, 2252, 3940, 1290, 2089, 2388, 5054, 1775, 2355, 1459, 14880, 10790, 1163, 3078, 2475, 13450, 1191, 2501, 3620, 9094, 4270, 7106, 5333, 4295, 26800, 4972, 2978, 4342, 9566, 1434, 991, 2710, 1789, 2538, 4155, 6666, 11460, 2385, 5506, 9793, 5895, 3282, 3145, 17080, 4262, 4923, 2311, 19040, 2157, 3589, 1615, 2463, 791, 1774, 3543, 13360, 4485, 5064, 11390, 3493, 2176, 1945, 1653, 4042, 2052, 1012, 3672, 7349, 1240, 17310, 1385, 2026, 1546, 7572, 9503, 4860, 5453, 2470, 2040, 3328, 2404, 3889, 3094, 760, 9031, 2589, 7315, 1104, 7212, 1364, 9916, 8115, 1529, 8966, 4412, 1780, 1850, 24910, 5340, 809, 3864, 1575, 2022, 14970, 3200, 2709, 3078, 1263, 9340, 3806, 7161, 2633, 1167, 2453, 1240, 1928, 1517, 1347, 5851, 3154, 3035, 28490, 1317, 15190, 2468, 5660, 6054, 1357, 3773, 17520, 4221, 16410, 9613, 2204, 8683, 2039, 15120, 9772, 1707, 2921, 5320, 2000, 6131, 5595, 1117, 3548, 1713, 1537, 4985, 2007, 1891, 11440, 3522
3464, 3416, 2759, 7531, 4011, 4719, 4089, 2409, 3105, 2511, 5810, 6070, 7686, 3781, 2042, 2487, 4345, 2760, 2960, 4246, 10640, 8070, 1902, 5351, 1554, 9285, 4790, 4641, 9039, 1500, 21310, 1862, 2578, 1669, 891, 11530, 1292, 21820, 2025, 9646, 12680, 1197, 9847, 20930, 2344, 16230, 4199, 5301, 4142, 1215, 19990, 1325, 1030, 1226, 2176, 1374, 1084, 6873, 1545, 4664, 9154, 1764, 1410, 8776, 13820, 4292, 10670, 3471, 3075, 4694, 1302, 2740, 2845, 10430, 2154, 8114, 2425, 1350, 9121, 3576, 1149, 1900, 2077, 6184, 3850, 19200, 1373, 1482, 2004, 3983, 3482, 1867, 3024, 13390, 6076, 1975, 2994, 1127, 1610, 3009, 3633, 1917, 2881, 2219, 4752, 6643, 7507, 1572, 4678, 4162, 1350, 5404, 17890, 1280, 2876, 10840, 4854, 3447, 2802, 8123, 5394, 3141, 2351, 2829, 14310, 1614, 1426, 4266, 8552, 3388, 1976, 7130, 8226, 6299, 3376, 4340, 6033, 5659, 10160, 9021, 11310, 2348, 3470, 2672, 4191, 3072, 2234, 2244, 5376, 8413, 1746, 4617, 6768, 6091, 6230, 6871, 23590, 1342, 13790, 9301, 10430, 1163, 15000, 2372, 3170, 2410, 5670, 15130, 5758, 27290, 1441, 6817, 3369, 1737, 2178, 1269, 8098, 1431, 11780, 3292, 14680, 2414, 6541, 4760, 4442, 3764, 5024, 1092, 12810, 2635, 9427, 4804, 8560, 19340, 2326, 7085, 2311, 16100, 4491, 2807, 9985, 2569, 4568, 2299, 1908, 1729, 13340, 1916, 1618, 2087, 1162, 4773, 3158, 15360, 1608, 8980, 2775, 10370, 8009, 8621, 6030, 2994, 1153, 1457, 14960, 8218, 3018, 815, 1466, 18000, 17560, 4230, 8158, 8642, 65 ...

# %% [markdown]
# ## Validando os campos numéricos

# %%
for item in df2.columns:
    try:
      print('{} :{} '.format(item,np.isnan(df2[item]).unique()))
    except:
      print(item, 'não verificado')
# print('{} :{} '.format(item,np.isnan(df2[item]).unique()))
# Out:
# city não verificado
# area :[False]
# rooms :[False]
# bathroom :[False]
# parking spaces :[False]
# floor não verificado
# animal não verificado
# furniture não verificado
# hoa (R$) :[False]
# rent amount (R$) :[False]
# property tax (R$) :[False]
# fire insurance (R$) :[False]
# total (R$) :[False]

# %%
df2.floor.unique()
# Out:
# array(['7', '20', '6', '2', '1', '-', '4', '3', '10', '11', '24', '9',
#        '8', '17', '18', '5', '13', '15', '16', '14', '26', '12', '21',
#        '19', '22', '27', '23', '35', '25', '46', '28', '29', '301', '51',
#        '32'], dtype=object)

# %% [markdown]
# ### Exportando DF para utilização na solução

# %%
df2.to_csv('/content/drive/MyDrive/Raiz/Faculdade/2021.1/IC/Trabalhos/Atividade 8 - Fuzzy/base_final.csv')

# %% [markdown]
# ###Uma aplicação da lógica fuzzy em sistemas de decisão:
# https://www.ime.unicamp.br/~cbsf4/Papers_IVCBSF/CBSF_2016_paper_56.pdf
